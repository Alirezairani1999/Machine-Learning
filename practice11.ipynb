# %%
import sys
print(sys.version)
# Out:
# 3.8.8 (default, Apr 13 2021, 15:08:03) [MSC v.1916 64 bit (AMD64)]

# %%
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import sklearn

# %%
start_time = time.time()
data = {'a': np.arange(500),
        'c': np.random.randint(0, 500, 500),
        'd': np.random.randn(500)}
data['b'] = data['a'] + 10 * np.random.randn(500)
data['d'] = np.abs(data['d']) * 100

plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()
df = pd.DataFrame(np.random.randn(10, 4)) 
print(df)

j=1.23
for i in range(80000000):
   j+=j    

print("\n-> Execution Time = %s in Seconds <-" % (time.time() - start_time))
# Out:
#           0         1         2         3
# 0  0.241844 -1.138664  0.853787  1.055103
# 1  1.547023 -0.493448 -0.537283 -1.356361
# 2 -0.979761  1.730533 -1.433242 -1.496961
# 3 -0.861352  2.137194 -0.761217 -0.642380
# 4  0.087500  1.163725 -0.286266 -0.055254
# 5 -0.739104 -0.041517 -0.306050  0.364428
# 6 -0.224126 -0.545076 -0.237922 -1.640651
# 7 -1.667675  0.448392  0.050849 -2.214803
# 8  1.304175 -0.358110  0.755673  0.029810
# 9 -0.599952  1.163852 -0.789707 -0.726123
#
# -> Execution Time = 23.238921403884888 in Seconds <-
